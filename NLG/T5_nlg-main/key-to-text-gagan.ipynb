# %%
# !pip install keytotext

# %%
from keytotext import pipeline

nlp = pipeline("k2t")

nlp(['Coffee','latte','please'])

# %%
from keytotext import pipeline

nlp = pipeline("k2t-base")

nlp(['Coffee','latte','please'])

# %%
from keytotext import pipeline

nlp = pipeline("mrm8488/t5-base-finetuned-common_gen")

nlp(['latte','1'])
